# %%
# download Glove and load it into torch.nn.Embedding and store the word2index in a dictionary
import torch
import numpy as np
from torchtext.vocab import GloVe
import torch.nn as nn 
import pickle
glove = GloVe(name='42B', dim=300)
word2index = glove.stoi
embedding_matrix = torch.zeros((len(word2index), 300))
embedding = nn.Embedding.from_pretrained(glove.vectors, freeze=False)

pickle.dump([embedding, word2index], open('../w2v/glove.300d.en.txt.pickle', 'wb'))

# %%
glove.itos[-2000:-1]
# Out:
# ['srart',
#  'sreading',
#  'srkajol',
#  'srt3',
#  '#ssl',
#  'sslave',
#  'ssl-cert',
#  'ssmn',
#  's-sure',
#  'st0-075',
#  'staffid',
#  'staffordshires',
#  'staffthursday',
#  'stafftuesday',
#  'stain-x',
#  'stakeholder-driven',
#  'stallions/hackney/redi-meds',
#  'stalwartuk',
#  'st-amant',
#  'stamp-size',
#  'stanchorage',
#  's.t.a.n.d.',
#  'standord',
#  'starfox64',
#  'starle',
#  'starmind',
#  'star-san',
#  'starselite',
#  'starsports',
#  'starspow',
#  'starsshineonme',
#  'start/continue',
#  'start.html',
#  'starthtml',
#  'star-type',
#  'starvox',
#  'starwagon',
#  'stasso',
#  'state10',
#  'statec',
#  'statementlicense',
#  'state.now',
#  'state-reported',
#  'states10/10/2012',
#  'statesquick',
#  'statesthere',
#  'states.washington',
#  'state_type',
#  'stateview',
#  'stathams',
#  'station/bryan',
#  'stationthis',
#  'statkevich',
#  'statsanswersboardvideos',
#  'statti',
#  'stay-awake',
#  'staybeautiful',
#  'stboise',
#  'std100',
#  'stduluth',
#  'steamfunk',
#  'steapon',
#  'steece',
#  'steelers/ravens',
#  'steelroots',
#  'stefanibags.com',
#  'steinhour',
#  'stellenbosh',
#  'step.if',
#  'stepkother',
#  'stepo',
#  'stepsjoincontact',
#  'step-step',
#  'stepups',
#  'steri-fab',
#  'sterioids',
#  'sterlinglogin',
#  'sternn',
#  'steroided',
#  'stevn',
#  'stgc',
#  'sthd',
#  'stnto',
#  'stock11',
#  'stock.estimated',
#  'stockfinster',
#  'stockholme',
#  'stockpickers',
#  'stockpiler',
#  'stocks.com',
#  'stockwarning',
#  'stocs',
#  'stokeham',
#  'stoke-on',
#  'stolder',
#  'stommelen',
#  'stone-covered',
#  'stooop',
#  'stopgame',
#  'stop/limit',
#  'storandt',
#  'storesbusinesses',
#  'stormclan',
#  'störmer',
#  'storm-relative',
#  'storyfebruary',
#  'story?follow',
#  'storywriters',
#  'stossell',
#  'stp2',
#  'straight-as-an-arrow',
#  'straight-axle',
#  'straight-foward',
#  'straightfromthea',
#  'straightguy',
#  'straightupknives',
#  'strangecharm',
#  'straschill',
#  'strata-g',
#  'stratching',
#  'strategysearchingusing',
#  'stratos-dev',
#  'streamconnection',
#  'streamingmedia',
#  'streetchattanooga',
#  'street-corners',
#  'street-scene',
#  'strelnieks',
#  'stress-level',
#  'strethall',
#  'strictured',
#  'string/cable',
#  'string.gsub',
#  'strinput',
#  's-trip',
#  'strobosoft',
#  'strool',
#  'strozek',
#  'struby',
#  'strzpon',
#  'stud/8',
#  'studcasino',
#  'student/faculty/staff',
#  'students.they',
#  'studfinder',
#  'studiomates',
#  'studna',
#  'studydog',
#  'stuff.when',
#  'stuntastic',
#  'stu-pid',
#  'styleadded',
#  'style.he',
#  'style-list',
#  'style-specific',
#  'styles.xml',
#  'style.they',
#  'styletto',
#  '#stylist',
#  'styork',
#  'su6',
#  'subagencies',
#  'sub-allocation',
#  'sub-bases',
#  'subdean',
#  'subgrouped',
#  'subj.',
#  'sublieutenant',
#  'subliminable',
#  'submassive',
#  'submityes',
#  'sub-oscillator',
#  'subseqently',
#  'substitutivity',
#  'sub-titling',
#  'sub-variety',
#  'subversion/trunk',
#  'successes/failures',
#  'success-the',
#  'succotz',
#  'sucrase-isomaltase',
#  'sucrette',
#  'sudala',
#  'suede/canvas',
#  'sueflohn',
#  'sueiro',
#  'sufferi',
#  'suffragio',
#  'sugarbutt',
#  'sugarfox',
#  'sugestii',
#  'suhrab',
#  'suicide/homicide',
#  'suis-jecute',
#  'su-jeong',
#  'sukina',
#  'sukkas',
#  'sulp',
#  'sulphurdunn',
#  'sulung',
#  'sumani',
#  'sumthg',
#  'sunandski.com',
#  'sunbeam-oster',
#  'sunfare',
#  'sunglasses-black',
#  'sunglassesuk.com',
#  'sung-woo',
#  'sunion',
#  'sun.jdbc.odbc.jdbcodbcdriver',
#  'sunki',
#  'sunnysports.com',
#  'sunrise.mp3',
#  'sun-seren-e',
#  'sun/son',
#  'sunstryk',
#  'superadobe',
#  'superbagnères',
#  'superbrace',
#  'supercena',
#  'super-collider',
#  'super-competent',
#  'super-condensed',
#  'supereffective',
#  'superfabulous',
#  'supergorge',
#  'supergym',
#  'superintendent/principal',
#  'superocho',
#  'superose',
#  'super-scientific',
#  'super-silent',
#  'superstripper',
#  'superstuds',
#  'super-v',
#  'supervillan',
#  'superzip',
#  'suplente',
#  'supnet',
#  'suppliesover',
#  'supplu',
#  'suppoter',
#  'supracompetitive',
#  'supraspinous',
#  'suremark',
#  'surepoint',
#  'surface-acoustic-wave',
#  'surface.false15',
#  'surface-supplied',
#  'surffers',
#  'surgeron',
#  'surgery/datas/pages',
#  'surgeryupdated',
#  'surkont',
#  'surper',
#  'suscribir',
#  'suspectoklahoma',
#  'suttkus',
#  'suutra',
#  'sv9',
#  'svāmī',
#  'svatební',
#  'svcpack',
#  'svcpo',
#  'sveet',
#  'svii',
#  'swaggtacular',
#  'swarens',
#  'sweef',
#  'swerski',
#  'swethasyam08',
#  'swim/bike',
#  'swim-good',
#  'swimsjit',
#  'swing.',
#  'swingings',
#  'swirko',
#  'switchmaster',
#  'swort',
#  'swugn',
#  'sx50hs',
#  'syahira',
#  'syde-sho',
#  '@sydney',
#  'symbos',
#  'symphonythe',
#  'syncroot',
#  'synctool',
#  'synovex',
#  'synthwork',
#  'system.collections.generic.ienumerable',
#  'systemdir',
#  'systems.there',
#  'system.web.ui.control',
#  'system.why',
#  'system.windows.threading.dispatcherobject',
#  'szafir',
#  'szhor',
#  'szklane',
#  'szumowska',
#  't008201',
#  't026201',
#  't032220',
#  't230h',
#  't-250',
#  't3pid',
#  't3xas',
#  't88iv',
#  "taabi'een",
#  'taanya',
#  'tabagisme',
#  'tabeer',
#  'table.html',
#  'tab-one',
#  'tabpages',
#  'tabytha',
#  'táctica',
#  'tadf',
#  'tae-kwon',
#  'tafu',
#  'tagatz',
#  'tagtile',
#  'tag-wiki',
#  't.a.h.',
#  'taihoku',
#  'tailtiu',
#  'takitez',
#  'takoe',
#  'talacen',
#  'talentamerica',
#  'talevi',
#  'talk-ca',
#  'talktv',
#  'tamborrada',
#  'tamini',
#  'tamtech',
#  'tamyia',
#  'tamyka',
#  'tán',
#  'tänder',
#  'tandingan',
#  'taneshima',
#  'tanglepatterns.com',
#  'tankster',
#  'tanks-to-pans',
#  'tannan',
#  'tannies',
#  'tannington',
#  'tansit',
#  'tanzawa',
#  'taonui',
#  'tape-in',
#  'taperd',
#  'tapvc',
#  'tarancon',
#  'taraska',
#  'tarax',
#  'tardugno',
#  'targard',
#  'targetdate',
#  'targetnasa',
#  'target-organ',
#  'targocid',
#  'tarien',
#  'tarmiya',
#  'tarmonbarry',
#  'tarrieth',
#  'tarzarnz',
#  'taskes',
#  'tasmanica',
#  'tasmans',
#  'tasn',
#  'tastarsupply',
#  'tataviam',
#  'tateosian',
#  'tatianolishka',
#  'tatlers',
#  'tats-unis604',
#  'tattooville',
#  'tauhan',
#  'távora',
#  'tavormina',
#  'tawatec',
#  'taxless',
#  'taxsaver',
#  'tax.sr',
#  'taybi',
#  '#taylorswift',
#  't.b.c',
#  't-bus',
#  'tcams',
#  't_constant_encapsed_string',
#  'tcontext',
#  'tcpglobal',
#  'tcserver',
#  'tcube',
#  't-diet',
#  'tdockery97',
#  'teacart',
#  'teacher-driven',
#  'téada',
#  'tea-for-classy-teddies',
#  'tealer',
#  'teal-green',
#  'teatments',
#  'techenclave',
#  'techfile',
#  'technologically-challenged',
#  'technology1987yes139',
#  'technology-obsessed',
#  'technologysocial',
#  'technosocial',
#  'technostructure',
#  'teckcocktail',
#  'tecro',
#  'tedtace',
#  'teenagey',
#  'teenanger',
#  'teen.gay.backdoor.buggery',
#  'teensteen',
#  'teenzs',
#  'teetotalling',
#  'tehsildars',
#  'teip',
#  'teipel',
#  'telcoiq',
#  'telcomm',
#  'telefinder',
#  'telefonmarketing',
#  'telefonultau',
#  'telephone-like',
#  'telephone-type',
#  'televizoare',
#  'telg',
#  'tempelncasino',
#  'temperates',
#  'tempo-based',
#  'temppath',
#  'tempusmaster',
#  'temudgin',
#  'tenaciousteens',
#  'tenbusch',
#  'tendacies',
#  'tendinae',
#  'tenniscourts',
#  'tennisdescription',
#  'tennouji',
#  'tenst',
#  'tentlike',
#  'teraview',
#  'tereu',
#  'terjemah',
#  'terkay',
#  'terlinden',
#  'terminalhotels',
#  'terminaron',
#  'terræ',
#  'terranium',
#  'terremoti',
#  'tersar',
#  'tert-butyldimethylsilyl',
#  'tertullianus',
#  'teschmacher',
#  'tesmec',
#  'testfunction',
#  'test-name',
#  'test-runs',
#  'test_version',
#  'tetrahexyldecyl',
#  'tetraoxide',
#  'teux',
#  'tew-432brp',
#  'tewaukon',
#  'texasgirly1979',
#  'texasman',
#  'texdent',
#  'textand',
#  'textbody',
#  'textid',
#  'textureimage',
#  'tf2banana',
#  'tfl/sacks',
#  'tfnj',
#  'tf.org',
#  'tf/sd',
#  'tg585',
#  'thaang',
#  'thanhv',
#  'thanks!diana',
#  'thankshi',
#  'thanks.refresh',
#  'thanks.we',
#  'that.does',
#  'thatdudeoverthere',
#  'thatgeeklover',
#  'that.john',
#  'that-not',
#  'that.other',
#  'thav',
#  'thawa',
#  'the33',
#  'theact',
#  'theahome.comcast.net',
#  'thealternativepress.com',
#  'theatre7',
#  'theatrein',
#  'theatre/theater',
#  'theblock',
#  'thebluedot.net',
#  'thecitymaker',
#  'thecoffee',
#  'thecombined',
#  'thecrowd',
#  'thedesigner',
#  'thefarm',
#  'thefatboylarry',
#  'thegamblingkingcasino',
#  'thegamersmag.com',
#  'thegetty',
#  'thegirlcantdance',
#  '@thehittvshow',
#  'thehut_group_outlet',
#  'theidiotshavewonthewar',
#  'theistically',
#  'the-largest',
#  'them.author',
#  'theme0',
#  'themes/skins',
#  'them.labels',
#  'them.serving',
#  'the.nightmare.before.christmas.1993.1080p.bluray.x264-cinefile',
#  'theoldiebutgoodie',
#  'théologique',
#  'theory3',
#  'therapeutische',
#  'there.next',
#  'therianthropes',
#  'thermo-compression',
#  'thermo-fused',
#  'therpeutic',
#  'the-science-llama',
#  'thetardisrocks',
#  'theunique',
#  'thewest.com.au',
#  'theworldmonitortv',
#  'thickr',
#  'thiefthe',
#  'thimothy',
#  'thinbody',
#  'things.just',
#  'thingsremembered.com',
#  'thinkhe',
#  'think-in',
#  'thinkprogress2',
#  'third-holiest',
#  'this.addeventlistener',
#  'thisblog',
#  'this.eventlistener',
#  'thisfirst',
#  'thisthank',
#  'this.view',
#  'thisweekend',
#  'thmcbb',
#  'thomasjefferson',
#  'thomathy',
#  'thornfalcon',
#  'thornhart',
#  'thorvaldur',
#  'thoughput',
#  'thpa',
#  'th?r',
#  'thrand',
#  'thrasyllus',
#  'thread.current',
#  'three-decades',
#  'three-plate',
#  'threnodies',
#  'thrg',
#  'thrif',
#  'thrillerthe',
#  'throuble',
#  'thunderstones',
#  'thurmonds',
#  'thursdaypm',
#  'thwo',
#  'tibbermore',
#  'ticketsdaughtry',
#  'ticketsmar',
#  'ticketszac',
#  'tierneylab',
#  'tierrafino',
#  'tigery',
#  'tight-fitted',
#  'tigil',
#  'tigy',
#  'tikorangi',
#  'tile-making',
#  'tilipia',
#  'timair',
#  'time-2',
#  'time-averaging',
#  'timedepartment',
#  'time_duration',
#  'timegenerated',
#  'timegroup',
#  'time-just',
#  'time.look',
#  'timeonline',
#  'time.pdf',
#  'timera',
#  'time-shifts',
#  'time-spent',
#  'timestimator',
#  'timethen',
#  'time-to-revenue',
#  'timitar',
#  'timora',
#  'tinchebray',
#  'tindink',
#  'tineye.com',
#  'tinually',
#  'tio_2',
#  'tipicamente',
#  'tips27search',
#  'tipsbrowns',
#  'tirapazamine',
#  'tiruppavai',
#  'titantrons',
#  'titemore',
#  'titions',
#  'titlelabel',
#  'titlelist',
#  'titletypeissue',
#  'tits.i',
#  'titsy',
#  'tittesworth',
#  'titularly',
#  'titute',
#  'tjakamarra',
#  'tjene',
#  'tjformal.com',
#  'tjinder',
#  'tjpc',
#  'tkachiev',
#  'tlady',
#  'tlistview',
#  '#tlok',
#  'tl-wr740n',
#  'tm32',
#  'tm60',
#  'tmch',
#  'tmmba',
#  'tmradmin',
#  'tm-u300',
#  'tn210y',
#  'tn57',
#  'tnnhc',
#  'tnni',
#  'tnuc',
#  'toastrack',
#  'to-be-healthy-and-fit',
#  'tobiume',
#  'tobriner',
#  'tocache',
#  'todayentertainment',
#  'today.many',
#  'today!news',
#  'toe-poked',
#  'toe-toe',
#  'toexamine',
#  'together10',
#  'together.how',
#  'toisa',
#  'tojohn',
#  'tokafi',
#  'tollerson',
#  'tom20',
#  'tom70',
#  'tomkats',
#  'tommy71',
#  'tommybruce',
#  'tomobile',
#  'tomvmorris',
#  'tonagura',
#  'toner2ink.com',
#  'tong-il',
#  'tongjitang',
#  'tonighttv',
#  'tonouchi',
#  'tonw',
#  'tony.',
#  'too!great',
#  'tooilet',
#  'tools.it',
#  'toolsupply',
#  'toolsweb',
#  'toooootally',
#  'tooshy',
#  'top42',
#  'topchapter',
#  'topica.com',
#  'topiccreate',
#  'topiclessbar',
#  'topics.for',
#  'topicsi',
#  'topnodust',
#  'topo50',
#  'topogr',
#  'topray',
#  'top-sheet',
#  'topwhite',
#  'torei',
#  'torgal',
#  'torikago',
#  'torqueless',
#  'torrentes',
#  'torrentzone',
#  'torres-gomez',
#  'torretti',
#  'torreyi',
#  'torz',
#  'totalconveyancing.com',
#  'totcount',
#  'totreat',
#  'touchcontagious',
#  'touchproof',
#  'toull',
#  'toulumne',
#  'touristische',
#  'touristplacesinindia.com',
#  'tourneyment',
#  'toursyou',
#  'tovmasyan',
#  'towamba',
#  'townall',
#  'townposted',
#  'toxin-laden',
#  'toxonics',
#  'toyokalon',
#  'toyota-camry',
#  'tpec',
#  'tpi2',
#  'trac-bugs',
#  'track-inspired',
#  'tracti',
#  'trafficks',
#  'trainerin',
#  'traintrack',
#  'trami',
#  'trammells',
#  'trancendent',
#  'trannt',
#  'transgranular',
#  'transip',
#  'transportables',
#  'transportacion',
#  'transportationsmoke',
#  'transsexuelles',
#  'trash-talks',
#  'travelagency',
#  'travelblogs',
#  'travelehome.com',
#  'travelgap',
#  'travellersour',
#  'travert',
#  'trayes',
#  'trayit',
#  'treatment-specific',
#  'tree8',
#  'treebeards',
#  'treemay',
#  'trees.mp3',
#  'tremewan',
#  'tremulus',
#  'trendelburg',
#  'treny',
#  'trethomas',
#  't-rev',
#  'trevison',
#  'treyarc',
#  'trhead',
#  'trianglecables',
#  'trichromacy',
#  'tricks/tips',
#  'tricorus',
#  'tridex',
#  'triggerred',
#  'tri-it',
#  'trimbles',
#  'trinbagonians',
#  'trinew',
#  'trinquet',
#  'trintec',
#  'tripadvisor_forum_support',
#  'triple-0',
#  'triple-flange',
#  'tripyou',
#  'tri-university',
#  'tri-vi-sol',
#  'trivora',
#  'tri-wheel',
#  'trixaicin',
#  'trockman',
#  'trofimuk',
#  'tromboning',
#  'tropie',
#  'tropinin',
#  'troponin-t',
#  'troubletown',
#  'troublicious',
#  'troupis',
#  'trowski',
#  'trrll',
#  'trsq',
#  'trüb',
#  'trubachev',
#  'truck-drivers',
#  'trucki',
#  'truckton',
#  'trudeaus',
#  'true/real',
#  'trumae',
#  'trumpster',
#  'truskey',
#  'trussed-up',
#  'trussian',
#  'trustconnect',
#  'trustedplaces',
#  'truz',
#  'try_first_pass',
#  'tryting',
#  'try-with-resources',
#  't_s',
#  'ts1m3',
#  'ts-559',
#  'tsaatan',
#  'tsangaris',
#  't-shirtdistressed',
#  'tstn',
#  't.string',
#  'tsuppari',
#  'tt2.tag',
#  'ttr125e',
#  't.u',
#  'tuesday.on',
#  'tufankjian',
#  'tulett',
#  'tumak',
#  'tumblrfashionbeans',
#  'tumblri',
#  'tundrasolutions',
#  'tunedin',
#  'tunejuice',
#  'tunewriter',
#  'tunnel-shaped',
#  'tuoch',
#  'tupeu',
#  'turnill',
#  'turn-on-a-dime',
#  'turn-to-mute',
#  'tuscanycasino',
#  'tutorials3d',
#  'tvmogel08',
#  'tvoice',
#  'tv-production',
#  'tvsdesign',
#  '@tvsportsmarkets',
#  'tvstandard',
#  'tvwith',
#  't-walls',
#  'tweetan',
#  'tweetread',
#  'tweetwall',
#  'twerktime',
#  'twgt',
#  'twicethe',
#  'twilyght',
#  'twin-hand',
#  'twinkl',
#  'twin-star',
#  'twin-tail',
#  'twitbacks',
#  'twitterjust',
#  'two-bedroom/two-bath',
#  'twonkyvision',
#  'two-o',
#  'two.that',
#  'two‑thirds',
#  'tx1200',
#  'txfemale',
#  'tx-sr875',
#  'tybsc',
#  'tymez',
#  'typ3',
#  'type_check',
#  'type-checker',
#  'type_main_variant',
#  'typo3_src-4',
#  'tyram',
#  'tyson-thomas',
#  'tyttenhanger',
#  'tzfujimino',
#  'u116',
#  'u2200',
#  'u436',
#  'u9gt2',
#  'u.b',
#  'ubermann',
#  'überprüfung',
#  'ubuntu/gnome',
#  'uchigatana',
#  'uddo',
#  'udongein',
#  'ueu',
#  'u+feff',
#  'ufonaut',
#  'ufs1/ufs2',
#  'uggaustralia.com',
#  'uglyhippieshit',
#  'ugly-pretty',
#  'u/h',
#  'uhul',
#  'uiga',
#  'uiimages',
#  'uintmax_t',
#  'uiop',
#  'uiscreen',
#  'ujire',
#  'ukali',
#  'uk/aus',
#  'uk.bl.ethos',
#  'uk/canada',
#  'uk.free',
#  'ukraine4',
#  'uk-skeptics',
#  'ukwir',
#  'ulad',
#  'ulamak',
#  'ulaş',
#  'ulbright',
#  'ulissi',
#  'ulla-maija',
#  'ul.menu',
#  'ulner',
#  'ultidev',
#  'ultilize',
#  'ultralott',
#  'ultra-natural',
#  'ultra-rest',
#  'ultrasonic-assisted',
#  'ultraviolet-induced',
#  'ultravpn',
#  'ultre',
#  'ultrices',
#  'ulwick',
#  'um150',
#  'umbellatus',
#  'umbertos',
#  'umbillical',
#  'umdm',
#  'umet',
#  'umichigan',
#  'unavailable-you',
#  'unbearables',
#  'unclothing',
#  'uncondition',
#  'under2000listeners',
#  'under-35s',
#  'underappreciation',
#  'undercarbonated',
#  'undercorrected',
#  'under-engineered',
#  'undergroundrailway',
#  'underhammer',
#  'under-react',
#  'under-stocked',
#  'under-tail',
#  'undewrear',
#  'undokai',
#  'undugu',
#  'unfallchirurg',
#  'un-french',
#  'ungi',
#  'unharassed',
#  'uni-color',
#  'unimar',
#  'un-imposed',
#  'unipi',
#  'uniprotkb/swiss',
#  'unique-sounding',
#  'unisciti',
#  'unitywater',
#  'universe.src',
#  'universitynational',
#  'universitynorth',
#  'university-september',
#  'unknown27',
#  'un-likely',
#  'unlimitied',
#  'unmanicured',
#  ...]

# %%
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
